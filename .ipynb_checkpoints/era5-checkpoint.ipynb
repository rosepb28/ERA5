# %% [markdown]
# ## Descarga de archivo del Era5

# %%
year = '2022'

year[-2:]
# Out:
# '22'

# %%
win = 'C:/Users/Rosamaria/Documents/GitHub/ERA5/NC/'
linux = '/home/rosamaria/Documentos/GitHub/ERA5/NC/'

import cdsapi

c = cdsapi.Client()
c.retrieve(
    'reanalysis-era5-pressure-levels-monthly-means',
    {
        'format': 'netcdf',
        'product_type': 'monthly_averaged_reanalysis',
        'variable': ['divergence', 'relative_humidity', 'specific_humidity',
            'temperature', 'u_component_of_wind', 'v_component_of_wind',
            'vertical_velocity', 'vorticity'],
        'pressure_level': ['200', '225', '250',
                            '300', '350', '400',
                            '450', '500', '550',
                            '600', '650', '700',
                            '950'],
        'year': 2022, 'month': 10, 'time': '00:00',
        'area': [30, -120, -60, -30],
    },
    linux + 'oct22.nc')

# %% [markdown]
# # Importando librerías

# %%
import os
from netCDF4 import Dataset
from netCDF4 import num2date
import numpy as np
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cartopy.io.shapereader as shpreader

import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap
from matplotlib import cm
from matplotlib.colors import ListedColormap,LinearSegmentedColormap

# %% [markdown]
# ### Lectura de archivo

# %%
file = "NC/ago22.nc"
data = Dataset(file)

#Lectura de variables (opcional)
#properties = []
#for v in data.variables.keys():
#    print('%-15s'%v,data.variables[v].long_name)

# %% [markdown]
# ### Función Cmap (barra de colores)

# %%
def c_cmap(file,sheet,clevs,inv=False):
    import pandas as pd
    from matplotlib.colors import ListedColormap, BoundaryNorm
    
    df = pd.read_excel(file,sheet) # lee el archivo excel y divide los valores entre 255
    df = df[['R','G','B']]/255
    if inv:
        df=df.iloc[::-1]   # Si es especificado invierte la barra de colores    
    cc=df.values.tolist()
    cmap = ListedColormap(cc[1:-1])
    cmap.set_under(cc[0])
    cmap.set_over(cc[-1])
    norm = BoundaryNorm(clevs,cmap.N)
    return cmap,norm

# %% [markdown]
# ### Conversión de coordenadas, tiempos y niveles

# %%
lt = data.variables['latitude'][:]
ln = data.variables['longitude'][:]
ln,lt = np.meshgrid(ln,lt)
times=data.variables['time']
vtimes = num2date(times[:], times.units)
levels = data['level'][:].tolist()

#Creación de folder donde se guardarán las imágenes
year = vtimes[0].strftime("%Y")
month = vtimes[0].strftime("%b")
folder='Img/{}/{}/'.format(year, month)
os.makedirs(folder) if not os.path.exists(folder) else 'No'
# Out:
# 'No'

# %% [markdown]
# ### 1. Imágenes de Sudamérica

# %% [markdown]
# ### - Líneas de corriente

# %%
n = 250
niv = levels.index(n) #Modificar nivel

u  = data.variables['u'][0,niv,:,:]
v  = data.variables['v'][0,niv,:,:]

levs = [0,5,10,15,20,25,30,35,40,50,60,65]
cmap, norm = c_cmap('Colores/lcorr.xlsx', '200', levs)

prj = ccrs.PlateCarree()
fig = plt.figure(figsize=(16,10.5), facecolor='white')
ax = plt.axes(projection = prj)

ax.add_feature(cfeature.BORDERS,edgecolor='k')
ax.add_feature(cfeature.COASTLINE,edgecolor='k')
gl = ax.gridlines(draw_labels=True,linestyle='--')
gl.top_labels = gl.right_labels = False
ax.set_extent([-120,-30,-50,15], crs=prj)

#Con color cambiante de acuerdo a la velocidad
sp = np.sqrt(u**2 + v**2)
lw = 5*sp / sp.max()
strm = ax.streamplot(ln, lt, u, v, color = sp, cmap=cmap,norm = norm, linewidth=0.8, density=9)
fig.colorbar(strm.lines, shrink = 0.8, extend='both')

fig.savefig(folder + 'lcorr{}.png'.format(str(n)), dpi=fig.dpi, bbox_inches= 'tight')

plt.show()

# %% [markdown]
# ### 2. Imágenes de Perú

# %% [markdown]
# ### - Divergencia

# %%
n = 200
div = data['d'][0,levels.index(n),:,:]*1e06
#levs = np.arange(-2,3,0.5)
levs=np.arange(-16,18,2)



#Creacion de colores
fig=plt.figure(figsize=(14,8.5),facecolor='white')
prj=ccrs.PlateCarree()
ax = plt.axes(projection=prj)

dir_shp = '../SHP/DEPARTAMENTOS.shp'
shp = list(shpreader.Reader(dir_shp).geometries())
ax.add_geometries(shp,prj,edgecolor='black',facecolor='None')
ax.add_feature(cfeature.BORDERS)
ax.add_feature(cfeature.COASTLINE)
#=============================================================================
gl = ax.gridlines(draw_labels=True,linestyle='--')
gl.top_labels = gl.right_labels = False
ax.set_extent([-85,-65,-22,5], crs=prj) #redomensionando
cx = ax.contourf(ln,lt,div,levs,transform=prj,cmap = 'RdBu_r', extend='both')
cc=plt.colorbar(cx,shrink=0.9,drawedges=True)

#plt.colorbar(cx)

#fig.savefig(folder + 'div{}.png'.format(str(n)), dpi=fig.dpi, bbox_inches= 'tight')

plt.show()

# %% [markdown]
# ### - Humedad relativa promedio

# %%
#Cálculo de HR promedio
r_sum = 0
u_sum = 0
v_sum = 0
for i in range(levels.index(600)+1):
    r = data['r'][0,i,:,:]
    u = data['u'][0,i,:,:]
    v = data['v'][0,i,:,:]
    r_sum = r_sum + r
    u_sum = u_sum + u
    v_sum = v_sum + v
hrp = (r_sum/len(levels[:levels.index(600)]))
up = (u_sum/len(levels[:levels.index(600)]))
vp = (v_sum/len(levels[:levels.index(600)]))

levs = np.arange(0,110,10)
cmap, norm = c_cmap('Colores/hrp2.xlsx', '550', levs)

fig=plt.figure(figsize=(14,8.5), facecolor='white')
prj=ccrs.PlateCarree()
ax = plt.axes(projection = prj)
cx = ax.contourf(ln,lt,hrp,levs, transform=prj, cmap=cmap, norm = norm, extend='both')
ax.quiver(ln[::4,::4],lt[::4,::4],up[::4,::4],vp[::4,::4], color = 'w', scale = 80)

#Límites de países y departamentos
dir_shp = '../SHP/DEPARTAMENTOS.shp'
shp = list(shpreader.Reader(dir_shp).geometries())
ax.add_geometries(shp,prj,edgecolor='black',facecolor='None')
ax.add_feature(cfeature.BORDERS)
ax.add_feature(cfeature.COASTLINE)
#Grillas y etiquetas de lat,lon
gl = ax.gridlines(draw_labels=True,linestyle='--')
gl.top_labels = gl.right_labels = False
ax.set_extent([-85,-65,-22,5], crs=prj)

plt.colorbar(cx)

#fig.savefig(folder + 'hrp.png'.format(month), dpi=fig.dpi, bbox_inches= 'tight')

plt.show()

# %% [markdown]
# ### - Humedad específica

# %%
niv = levels.index(550) #Modificar nivel
q = data['q'][0,niv,:,:]*1000
u  = data.variables['u'][0,niv,:,:]
v  = data.variables['v'][0,niv,:,:]

#levs = np.arange(4,7,0.5)
levs = np.arange(3,6,0.5)
cmap, norm = c_cmap('Colores/rmix.xlsx', '550', levs)

fig=plt.figure(figsize=(14,8.5), facecolor='white')
prj=ccrs.PlateCarree()
ax = plt.axes(projection = prj)

sn = 5
cx = ax.contourf(ln,lt,q,levs, transform=prj, cmap=cmap, norm= norm, extend='both')
ax.quiver(ln[::sn,::sn],lt[::sn,::sn],u[::sn,::sn],v[::sn,::sn], color = 'k', scale = 50, headwidth=5, headlength=6)

#Límites de países y departamentos
dir_shp = '../SHP/DEPARTAMENTOS.shp'
shp = list(shpreader.Reader(dir_shp).geometries())
ax.add_geometries(shp,prj,edgecolor='black',facecolor='None')
ax.add_feature(cfeature.BORDERS)
ax.add_feature(cfeature.COASTLINE)
#Grillas y etiquetas de lat,lon
gl = ax.gridlines(draw_labels=True,linestyle='--')
gl.top_labels = gl.right_labels = False
ax.set_extent([-85,-65,-22,5], crs=prj)

plt.colorbar(cx)


#fig.savefig(folder + 'q550.png'.format(month), dpi=fig.dpi, bbox_inches= 'tight')

plt.show()

# %% [markdown]
# ### - Temperatura potencial equivalente

# %%
lat = data.variables['latitude'][100:201]
lon = data.variables['longitude'][120:221]
lon,lat = np.meshgrid(lon,lat)
niv = levels.index(950) #Modificar nivel

t  = data.variables['t'][0,niv,100:201,120:221]
r = data['r'][0,niv,100:201,120:221]
u  = data.variables['u'][0,niv,100:201,120:221]
v  = data.variables['v'][0,niv,100:201,120:221]

es=6.11*pow(10,((7.5*(t-273))/(237.5+(t-273))))
e=es*r/100
rm=0.622*e/(950-e)
te=t*(1+(2529.8804*rm/t))
tpe=te*pow(1000/950,0.286)

levs = np.arange(306,332,2)
cmap, norm = c_cmap('Colores/tpe.xlsx', '950', levs)

fig=plt.figure(figsize=(14,8.5), facecolor='white')
prj=ccrs.PlateCarree()
ax = plt.axes(projection = prj)
sn = 7
cx = ax.contourf(lon,lat,tpe.round(2),levs, transform=prj, cmap=cmap, norm= norm, extend='both')
cs = ax.contour(lon,lat,tpe.round(2),levs,transform=prj, colors='w',linewidths=0.8)
ax.clabel(cs, cs.levels[6:], colors='k', inline=1, fontsize=10, inline_spacing=1)
ax.quiver(lon[::sn,::sn],lat[::sn,::sn],u[::sn,::sn],v[::sn,::sn],
          color = 'k', scale = 200, headwidth=3, headlength=3)

#Límites de países y departamentos
dir_shp = '../SHP/DEPARTAMENTOS.shp'
shp = list(shpreader.Reader(dir_shp).geometries())
ax.add_geometries(shp,prj,edgecolor='black',facecolor='None')
ax.add_feature(cfeature.BORDERS)
ax.add_feature(cfeature.COASTLINE)
#Grillas y etiquetas de lat,lon
gl = ax.gridlines(draw_labels=True,linestyle='--')
gl.top_labels = gl.right_labels = False
ax.set_extent([-90,-65,-20,5], crs=prj)

plt.colorbar(cx)

fig.savefig(folder + 'tpe950.png'.format(month), dpi=fig.dpi, bbox_inches= 'tight')

plt.show()

# %%
tpe.round(2)
# Out:
# masked_array(
#   data=[[336.18, 336.1, 336.14, ..., 343.57, 348.92, 346.38],
#         [335.57, 335.53, 335.45, ..., 346.77, 347.69, 344.77],
#         [334.96, 334.81, 334.81, ..., 351.23, 349.26, 345.89],
#         ...,
#         [308.9, 308.81, 308.69, ..., 325.56, 324.0, 323.94],
#         [308.81, 308.72, 308.59, ..., 323.76, 323.31, 323.19],
#         [308.65, 308.58, 308.46, ..., 319.96, 321.88, 324.7]],
#   mask=[[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#   fill_value=1e+20)
