# %%
from era5_graphs import era5_download, lcorr, divergencia, sp_hum, hrp600_200, tpe

# %%
era5_download(11, 2022, 'linux')
# Out:
# 2022-12-12 17:20:53,530 INFO Welcome to the CDS
# 2022-12-12 17:20:53,532 INFO Sending request to https://cds.climate.copernicus.eu/api/v2/resources/reanalysis-era5-pressure-levels-monthly-means
# 2022-12-12 17:20:53,842 INFO Request is queued
# 2022-12-12 17:20:55,079 INFO Request is running
# 2022-12-12 17:21:02,854 INFO Request is completed
# 2022-12-12 17:21:02,856 INFO Downloading https://download-0001-clone.copernicus-climate.eu/cache-compute-0001/cache/data4/adaptor.mars.internal-1670883658.4334297-15618-7-f9789939-2369-42d6-a204-d618d01b4e8c.nc to /home/rosamaria/Documentos/GitHub/ERA5/NC/nov22.nc (25.9M)
# 2022-12-12 17:21:09,682 INFO Download rate 3.8M/s
# Archivo descargado.

# %%
ruta = "NC/nov22.nc"

lcorr(file = ruta, save_png='no')
divergencia(file = ruta, save_png='no')
sp_hum(file = ruta, save_png='no')
hrp600_200(file = ruta, save_png='no')
tpe(file = ruta, save_png='no')
