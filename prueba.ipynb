# %%
from era5_graphs import lcorr, divergencia, sp_hum, hrp600_200, tpe

ruta = "NC/oct22.nc"

lcorr(file = ruta, save_png='yes')
divergencia(file = ruta, save_png='yes')
sp_hum(file = ruta, save_png='yes')
hrp600_200(file = ruta, save_png='yes')
tpe(file = ruta, save_png='yes')
